# %%
# Laços e iteração

print ("Ola mundo")
print ("Ola mundo")
print ("Ola mundo")
print ("Ola mundo")
print ("Ola mundo")
print ("Ola mundo")
# Out:
# Ola mundo
# Ola mundo
# Ola mundo
# Ola mundo
# Ola mundo
# Ola mundo

# %%
for i in range (7):
  print ("Grupo A")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range (7):

  print (0 + i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
palavra = "python"
invertida = ""

for i in (palavra):
 invertida = i + invertida
 print (invertida)
# Out:
# p
# yp
# typ
# htyp
# ohtyp
# nohtyp

# %%
# Escrever um programa  que o usuario digita uma palavrae e o programa
# Verifica se a palavra é palindroma e  imprime a palavra

# entrada
palavra = str (input("Digite uma palavra: "))
invertida = ""

for in (palavra):

   invertida = i + invertida

   if invertida == palavra:

    print (f"{palavra} é uma palavra palidroma ")

    else :

      print("A palavra {palavra} nao e polidroma")
# Out:
#   File "/tmp/ipykernel_4055/2816274519.py", line 8
#     for in (palavra):
#         ^
# SyntaxError: invalid syntax

# %%
# Escrever um programa que o usuario digita um numero e o programa imprime os
# numeros pares de zero ate o numero.
